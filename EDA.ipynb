# %%
# import dependencies
import pandas as pd
import os

# %%
# Read the housing data into a panda dataframe
temp = os.path.join("Resources","Housing_Market_Inventory_US.csv")
Housing_sample_data = pd.read_csv(temp)
Housing_sample_data.head()
# Out:
#    month_date_yyyymm  postal_code         zip_name  median_listing_price  \
# 0             202204        49677    reed city, mi              139900.0
# 1             202204        32621      bronson, fl              429000.0
# 2             202204        28040    ellenboro, nc              550000.0
# 3             202204        64163  kansas city, mo              269950.0
# 4             202204        39203      jackson, ms               25000.0
#
#    active_listing_count  median_days_on_market  new_listing_count  \
# 0                   6.0                     41                8.0
# 1                   5.0                    175                0.0
# 2                  11.0                     34               12.0
# 3                   4.0                     53                8.0
# 4                   3.0                     48                0.0
#
#    price_increased_count  price_reduced_count  pending_listing_count  \
# ...

# %%
# Count the values in the dataframe
Housing_sample_data.count()
# Out:
# month_date_yyyymm                       1048575
# postal_code                             1048575
# zip_name                                1048575
# median_listing_price                    1046016
# active_listing_count                    1046016
# median_days_on_market                   1048575
# new_listing_count                       1046813
# price_increased_count                   1046813
# price_reduced_count                     1046813
# pending_listing_count                    856619
# median_listing_price_per_square_foot    1033648
# median_square_feet                      1033648
# average_listing_price                   1046016
# total_listing_count                     1046813
# pending_ratio                            855852
# quality_flag                            1048575
# dtype: int64

# %%
# Count the Null values
Housing_sample_data.isnull().sum()
# Out:
# month_date_yyyymm                            0
# postal_code                                  0
# zip_name                                     0
# median_listing_price                      2559
# active_listing_count                      2559
# median_days_on_market                        0
# new_listing_count                         1762
# price_increased_count                     1762
# price_reduced_count                       1762
# pending_listing_count                   191956
# median_listing_price_per_square_foot     14927
# median_square_feet                       14927
# average_listing_price                     2559
# total_listing_count                       1762
# pending_ratio                           192723
# quality_flag                                 0
# dtype: int64

# %%
Housing_sample_data.dtypes
# Out:
# month_date_yyyymm                         int64
# postal_code                               int64
# zip_name                                 object
# median_listing_price                    float64
# active_listing_count                    float64
# median_days_on_market                     int64
# new_listing_count                       float64
# price_increased_count                   float64
# price_reduced_count                     float64
# pending_listing_count                   float64
# median_listing_price_per_square_foot    float64
# median_square_feet                      float64
# average_listing_price                   float64
# total_listing_count                     float64
# pending_ratio                           float64
# quality_flag                              int64
# dtype: object

# %%
# Read the housing data into a panda dataframe
temp_covid = os.path.join("Resources","United_States_COVID-19_Cases_and_Deaths.csv")
covid_sample_data = pd.read_csv(temp_covid)
covid_sample_data.head()
# Out:
#   submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0      03/18/2021    NE     206980         NaN         NaN       298
# 1      09/01/2021    ND     118491    107475.0     11016.0       536
# 2      10/04/2020    MD     127290         NaN         NaN       471
# 3      02/06/2020    NE          0         NaN         NaN         0
# 4      10/06/2021    DE     134690    124148.0     10542.0       444
#
#    pnew_case  tot_death
# 0        0.0       2130
# 1       66.0       1562
# 2        0.0       4092
# 3        NaN          0
# 4       45.0       1977

# %%
# Count the values in the dataframe
covid_sample_data.count()
# Out:
# submission_date    50481
# state              50481
# tot_cases          50481
# conf_cases         27959
# prob_cases         27887
# new_case           50481
# pnew_case          46779
# tot_death          50481
# dtype: int64

# %%
# Count the Null values
covid_sample_data.isnull().sum()
# Out:
# submission_date        0
# state                  0
# tot_cases              0
# conf_cases         22522
# prob_cases         22594
# new_case               0
# pnew_case           3702
# tot_death              0
# dtype: int64

# %%
# Count the Null values
covid_sample_data.dtypes
# Out:
# submission_date     object
# state               object
# tot_cases            int64
# conf_cases         float64
# prob_cases         float64
# new_case             int64
# pnew_case          float64
# tot_death            int64
# dtype: object

# %%
# Read the housing data into a panda dataframe
temp_income = os.path.join("Resources","Zip_Income.xlsx")
income_sample_data = pd.read_excel(temp_income)
income_sample_data.head()
# Out:
#                                             NEBRASKA  \
# 0  Individual Income Tax Returns: \nSelected Inco...
# 1        [Money amounts are in thousands of dollars]
# 2                                      ZIP\ncode [1]
# 3                                                NaN
# 4                                                NaN
#
#                       Unnamed: 1             Unnamed: 2
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2  Size of adjusted gross income  Number of returns [2]
# 3                            NaN                    NaN
# 4                            NaN                     -1

# %%
# Read the population data into a panda dataframe
temp_population = os.path.join("Resources","Zip_Population.xlsx")
population_sample_data = pd.read_excel(temp_population)
population_sample_data.head()
# Out:
#    zip       lat       lng       city state_id   state_name  zcta  \
# 0  601  18.18027 -66.75266   Adjuntas       PR  Puerto Rico  True
# 1  602  18.36075 -67.17541     Aguada       PR  Puerto Rico  True
# 2  603  18.45744 -67.12225  Aguadilla       PR  Puerto Rico  True
# 3  606  18.16585 -66.93716    Maricao       PR  Puerto Rico  True
# 4  610  18.29110 -67.12243     Anasco       PR  Puerto Rico  True
#
#    parent_zcta  population  density  county_fips county_name  \
# 0          NaN     16773.0    100.5        72001    Adjuntas
# 1          NaN     37083.0    472.1        72003      Aguada
# 2          NaN     45652.0    513.2        72005   Aguadilla
# 3          NaN      6231.0     54.3        72093     Maricao
# 4          NaN     26502.0    275.7        72011      Añasco
#
#                                       county_weights  \
# 0                    {"72001": 98.76, "72141": 1.24}
# 1                                     {"72003": 100}
# ...
